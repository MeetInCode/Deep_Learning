# %%
import numpy as np
import pandas as pd
import time

# %%
df = pd.read_csv('/content/Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df = df[['Age','EstimatedSalary','Purchased']]

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (400, 2)

# %%
#from sklearn.model_selection import train_test_split
#X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
#X_train.shape

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 151 (604.00 B)
#  Trainable params: 151 (604.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
start = time.time()
history = model.fit(X_scaled,y,epochs=15,batch_size=1,validation_split=0.2)
print(time.time() - start)
# Out:
# Epoch 1/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8837 - loss: 0.2901 - val_accuracy: 0.9875 - val_loss: 0.1567
# Epoch 2/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8937 - loss: 0.2961 - val_accuracy: 0.9875 - val_loss: 0.1559
# Epoch 3/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8788 - loss: 0.2523 - val_accuracy: 0.9750 - val_loss: 0.1562
# Epoch 4/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8734 - loss: 0.3117 - val_accuracy: 0.9875 - val_loss: 0.1538
# Epoch 5/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8849 - loss: 0.2850 - val_accuracy: 0.9875 - val_loss: 0.1540
# Epoch 6/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8716 - loss: 0.2959 - val_accuracy: 0.9750 - val_loss: 0.1587
# Epoch 7/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8834 - loss: 0.3300 - val_accuracy: 0.9875 - val_loss: 0.1541
# Epoch 8/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9126 - loss: 0.2161 - val_accuracy: 0.9750 - val_loss: 0.1458
# Epoch 9/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9404 - loss: 0.1747 - val_accuracy: 0.9750 - val_loss: 0.1526
# Epoch 10/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9151 - loss: 0.2173 - val_accuracy: 0.9750 - val_loss: 0.1519
# Epoch 11/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8799 - loss: 0.3052 - val_accuracy: 0.9875 - val_loss: 0.1441
# Epoch 12/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9211 - loss: 0.2124 - val_accuracy: 0.9875 - val_loss: 0.1479
# Epoch 13/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8815 - loss: 0.3073 - val_accuracy: 0.9875 - val_loss: 0.1447
# Epoch 14/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9154 - loss: 0.2356 - val_accuracy: 0.9750 - val_loss: 0.1476
# Epoch 15/15
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9019 - loss: 0.3160 - val_accuracy: 0.9875 - val_loss: 0.1409
# 19.229219913482666

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
#start = time.time()
history = model.fit(X_scaled,y,epochs=15,batch_size=250,validation_split=0.2)
#print(time.time() - start)
# Out:
# Epoch 1/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step - accuracy: 0.8101 - loss: 0.4484 - val_accuracy: 0.7125 - val_loss: 0.6401
# Epoch 2/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7954 - loss: 0.4487 - val_accuracy: 0.7125 - val_loss: 0.6386
# Epoch 3/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8074 - loss: 0.4414 - val_accuracy: 0.7250 - val_loss: 0.6375
# Epoch 4/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8048 - loss: 0.4347 - val_accuracy: 0.7125 - val_loss: 0.6369
# Epoch 5/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8008 - loss: 0.4338 - val_accuracy: 0.7125 - val_loss: 0.6336
# Epoch 6/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8129 - loss: 0.4270 - val_accuracy: 0.7125 - val_loss: 0.6315
# Epoch 7/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8062 - loss: 0.4226 - val_accuracy: 0.7125 - val_loss: 0.6302
# Epoch 8/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8043 - loss: 0.4260 - val_accuracy: 0.7125 - val_loss: 0.6300
# Epoch 9/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8104 - loss: 0.4186 - val_accuracy: 0.7125 - val_loss: 0.6283
# Epoch 10/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8205 - loss: 0.4108 - val_accuracy: 0.7250 - val_loss: 0.6256
# Epoch 11/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8239 - loss: 0.4095 - val_accuracy: 0.7125 - val_loss: 0.6220
# Epoch 12/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8266 - loss: 0.4073 - val_accuracy: 0.7250 - val_loss: 0.6201
# Epoch 13/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8266 - loss: 0.4014 - val_accuracy: 0.7250 - val_loss: 0.6184
# Epoch 14/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8212 - loss: 0.4050 - val_accuracy: 0.7375 - val_loss: 0.6181
# Epoch 15/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8267 - loss: 0.4010 - val_accuracy: 0.7375 - val_loss: 0.6157

# %%
plt.plot(history.history['loss'])
